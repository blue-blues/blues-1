# %%
# %%
from huggingface_hub import snapshot_download

# %%
snapshot_download(repo_id="blue-blue/final_medical",local_dir="blues-1/data",repo_type="dataset")

# %%
snapshot_download(repo_id="karpathy/fineweb-edu-100B-gpt2-token-shards",local_dir="blues-1/data",repo_type="dataset")

# %%
from huggingface_hub import login
from huggingface_hub import HfApi

login(token='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')



# %%
api = HfApi()
api.upload_folder(
    folder_path="/root/blues-1/dataset/HuggingFaceFW/fineweb-edu",
    repo_id="blue-blue/final_medical",
    repo_type="dataset",
)

# %%
import torch
model = TheModelClass(*args, **kwargs)

model.load_state_dict(torch.load('/root/model_05000.pt', map_location=torch.device('cpu')))


# %%
from a import GPTConfig

model = torch.load('/root/model_05000.pt', map_location=torch.device('cpu'))


# %%
batch_size = 8 

# %%
